# %%
import numpy as np
import cv2
from sklearn.cluster import KMeans

import random
import utils
import BoW


import time
# %matplotlib inline

# %%
bag_of_words_dataset = utils.Caltech_256_Dataset(drop_rate = 0.92)

# %%
kmeans_model = BoW.generate_kmeans_model(bag_of_words_dataset.get_data_X(), 
                                     1024, 32, 16, 20000, verbose = True)
# Out:
# number of images: 2524
# 0 images finished.
# 500 images finished.
# 1000 images finished.
# 1500 images finished.
# 2000 images finished.
# 2500 images finished.
# number of all patches 2524
# number of samples used in Kmeans clustering: 20000
# Start training Kmeans model.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-2d86e6038733> in <module>
#       1 kmeans_model = BoW.generate_kmeans_model(bag_of_words_dataset.get_data_X(),
# ----> 2                                      1024, 32, 16, 20000, verbose = True)
#
# E:\cv\A2\BoW.py in generate_kmeans_model(data, dim, patch_size, step_size, number_of_samples, verbose)
#      92     all_patches_arr = all_patches_arr[all_patches]
#      93     print("number of samples used in Kmeans clustering:", all_patches.shape[0])
# ---> 94     print("Start training Kmeans model.")
# ...

# %%
import pickle

filename = 'kmeans_model.sav'
pickle.dump(kmeans_model, open(filename, 'wb'))

# %%
import pickle

filename = 'kmeans_model.sav'
kmeans_model = pickle.load(open(filename, 'rb'))

# %%
a = utils.read_image("test.jpg")

# %%
utils.show_image(a, "a")

# %%
a = BoW.generating_patches_rep(a, 16, 32)
feature_vec = np.zeros(1024)
a = np.array(a)

kmeans_model.predict(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-02c27b3d6a5b> in <module>
# ----> 1 a = BoW.generating_patches_rep(a, 16, 32)
#       2 feature_vec = np.zeros(1024)
#       3 a = np.array(a)
#       4
#       5 kmeans_model.predict(a)
#
# NameError: name 'a' is not defined

# %%
import time

t = time.time()
for i in range(1000):
    BoW.generating_patches_rep_unroll(a, 16, 32)
print(time.time() - t)

t = time.time()
for i in range(1000):
    BoW.generating_patches_rep(a, 16, 32)
print(time.time() - t)
# Out:
# 17.073158264160156
# 16.994311809539795
