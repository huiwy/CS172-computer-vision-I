# %%
import torchvision.models as models
from torch import nn
from torchscan import summary
import torch

# %%
densenet = models.densenet169( pretrained=False )

# %%
class UpSample(nn.Module):
    def __init__(self, in_c, out_c):
        super(UpSample, self).__init__()
        self.upsample = nn.Upsample(scale_factor=2, mode = 'bilinear')
        self.conv1 = nn.Conv2d(in_c, out_c, kernel_size=3, padding=1)
        self.relu1 = nn.LeakyReLU(0.2)
        self.conv2 = nn.Conv2d(out_c, out_c, kernel_size=3, padding=1)
        self.relu2 = nn.LeakyReLU(0.2)
    def forward(self, x, concat):
        x = self.upsample(x)
        x = torch.cat([x, concat], dim=1)
        x = self.relu1(self.conv1(x))
        x = self.relu2(self.conv2(x))
        return x
    
class DepthNet(nn.Module):
    def __init__(self, pretrained = True):
        super(DepthNet, self).__init__()
        densenet = models.densenet169(pretrained)
        # Densenet backbone
        self.conv1 = densenet.features[0]
        self.block1 = nn.Sequential(*(densenet.features[1:4]))
        self.block2 = nn.Sequential(*(densenet.features[4:6]))
        self.block3 = nn.Sequential(*(densenet.features[6:8]))
        self.block4 = nn.Sequential(*(densenet.features[8:-1]))
        self.conv2 = nn.Conv2d(1664, 1664, 1)
        self.upsample1 = UpSample(1920, 832)
        self.upsample2 = UpSample(960, 416)
        self.upsample3 = UpSample(480, 208)
        self.upsample4 = UpSample(272, 104)
        self.conv3 = nn.Conv2d(104, 104, 3, padding=1)
    def forward(self, x):
        c1 = self.conv1(x)
        c2 = self.block1(c1)
        c3 = self.block2(c2)
        c4 = self.block3(c3)
        x = self.block4(c4)
        x = self.conv2(x)
        x = self.upsample1(x, c4)
        x = self.upsample2(x, c3)
        x = self.upsample3(x, c2)
        x = self.upsample4(x, c1)
        return self.conv3(x)

# %%
densenet.features[4:6]
# Out:
# Sequential(
#   (denseblock1): _DenseBlock(
#     (denselayer1): _DenseLayer(
#       (norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU(inplace=True)
#       (conv1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu2): ReLU(inplace=True)
#       (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (denselayer2): _DenseLayer(
#       (norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU(inplace=True)
#       (conv1): Conv2d(96, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu2): ReLU(inplace=True)
#       (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (denselayer3): _DenseLayer(
#       (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU(inplace=True)
#       (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu2): ReLU(inplace=True)
#       (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (denselayer4): _DenseLayer(
#       (norm1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU(inplace=True)
#       (conv1): Conv2d(160, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu2): ReLU(inplace=True)
#       (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (denselayer5): _DenseLayer(
#       (norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU(inplace=True)
#       (conv1): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu2): ReLU(inplace=True)
#       (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (denselayer6): _DenseLayer(
#       (norm1): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU(inplace=True)
#       (conv1): Conv2d(224, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu2): ReLU(inplace=True)
#       (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#   )
#   (transition1): _Transition(
#     (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   )
# )

# %%
depthnet = DepthNet(False).float()

# %%
summary(depthnet, (3, 480, 640))
# Out:
# D:\Anaconda\envs\torch\lib\site-packages\torch\nn\functional.py:3060: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   warnings.warn("Default upsampling behavior when mode={} is changed "
# D:\Anaconda\envs\torch\lib\site-packages\torchscan\modules\flops.py:64: UserWarning: Module type not supported: Upsample
#   warnings.warn(f'Module type not supported: {module.__class__.__name__}')
# D:\Anaconda\envs\torch\lib\site-packages\torchscan\modules\macs.py:51: UserWarning: Module type not supported: Upsample
#   warnings.warn(f'Module type not supported: {module.__class__.__name__}')
# D:\Anaconda\envs\torch\lib\site-packages\torchscan\modules\memory.py:57: UserWarning: Module type not supported: Upsample
#   warnings.warn(f'Module type not supported: {module.__class__.__name__}')
# D:\Anaconda\envs\torch\lib\site-packages\torchscan\modules\receptive.py:46: UserWarning: Module type not supported: Upsample
#   warnings.warn(f'Module type not supported: {module.__class__.__name__}')
# __________________________________________________________________________________________
# Layer                        Type                  Output Shape              Param #
# ==========================================================================================
# depthnet                     DepthNet              (-1, 104, 240, 320)       0
# ├─conv1                      Conv2d                (-1, 64, 240, 320)        9,408
# ├─block1                     Sequential            (-1, 64, 120, 160)        0
# |    └─0                     BatchNorm2d           (-1, 64, 240, 320)        257
# |    └─1                     ReLU                  (-1, 64, 240, 320)        0
# |    └─2                     MaxPool2d             (-1, 64, 120, 160)        0
# ├─block2                     Sequential            (-1, 128, 60, 80)         0
# |    └─0                     _DenseBlock           (-1, 256, 120, 160)       0
# |    |    └─denselayer1      _DenseLayer           (-1, 32, 120, 160)        0
# |    |    |    └─norm1       BatchNorm2d           (-1, 64, 120, 160)        257
# |    |    |    └─relu1       ReLU                  (-1, 64, 120, 160)        0
# |    |    |    └─conv1       Conv2d                (-1, 128, 120, 160)       8,192
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 120, 160)       513
# |    |    |    └─relu2       ReLU                  (-1, 128, 120, 160)       0
# |    |    |    └─conv2       Conv2d                (-1, 32, 120, 160)        36,864
# |    |    └─denselayer2      _DenseLayer           (-1, 32, 120, 160)        0
# |    |    |    └─norm1       BatchNorm2d           (-1, 96, 120, 160)        385
# |    |    |    └─relu1       ReLU                  (-1, 96, 120, 160)        0
# |    |    |    └─conv1       Conv2d                (-1, 128, 120, 160)       12,288
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 120, 160)       513
# |    |    |    └─relu2       ReLU                  (-1, 128, 120, 160)       0
# |    |    |    └─conv2       Conv2d                (-1, 32, 120, 160)        36,864
# |    |    └─denselayer3      _DenseLayer           (-1, 32, 120, 160)        0
# |    |    |    └─norm1       BatchNorm2d           (-1, 128, 120, 160)       513
# |    |    |    └─relu1       ReLU                  (-1, 128, 120, 160)       0
# |    |    |    └─conv1       Conv2d                (-1, 128, 120, 160)       16,384
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 120, 160)       513
# |    |    |    └─relu2       ReLU                  (-1, 128, 120, 160)       0
# |    |    |    └─conv2       Conv2d                (-1, 32, 120, 160)        36,864
# |    |    └─denselayer4      _DenseLayer           (-1, 32, 120, 160)        0
# |    |    |    └─norm1       BatchNorm2d           (-1, 160, 120, 160)       641
# |    |    |    └─relu1       ReLU                  (-1, 160, 120, 160)       0
# |    |    |    └─conv1       Conv2d                (-1, 128, 120, 160)       20,480
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 120, 160)       513
# |    |    |    └─relu2       ReLU                  (-1, 128, 120, 160)       0
# |    |    |    └─conv2       Conv2d                (-1, 32, 120, 160)        36,864
# |    |    └─denselayer5      _DenseLayer           (-1, 32, 120, 160)        0
# |    |    |    └─norm1       BatchNorm2d           (-1, 192, 120, 160)       769
# |    |    |    └─relu1       ReLU                  (-1, 192, 120, 160)       0
# |    |    |    └─conv1       Conv2d                (-1, 128, 120, 160)       24,576
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 120, 160)       513
# |    |    |    └─relu2       ReLU                  (-1, 128, 120, 160)       0
# |    |    |    └─conv2       Conv2d                (-1, 32, 120, 160)        36,864
# |    |    └─denselayer6      _DenseLayer           (-1, 32, 120, 160)        0
# |    |    |    └─norm1       BatchNorm2d           (-1, 224, 120, 160)       897
# |    |    |    └─relu1       ReLU                  (-1, 224, 120, 160)       0
# |    |    |    └─conv1       Conv2d                (-1, 128, 120, 160)       28,672
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 120, 160)       513
# |    |    |    └─relu2       ReLU                  (-1, 128, 120, 160)       0
# |    |    |    └─conv2       Conv2d                (-1, 32, 120, 160)        36,864
# |    └─1                     _Transition           (-1, 128, 60, 80)         0
# |    |    └─norm             BatchNorm2d           (-1, 256, 120, 160)       1,025
# |    |    └─relu             ReLU                  (-1, 256, 120, 160)       0
# |    |    └─conv             Conv2d                (-1, 128, 120, 160)       32,768
# |    |    └─pool             AvgPool2d             (-1, 128, 60, 80)         0
# ├─block3                     Sequential            (-1, 256, 30, 40)         0
# |    └─0                     _DenseBlock           (-1, 512, 60, 80)         0
# |    |    └─denselayer1      _DenseLayer           (-1, 32, 60, 80)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 128, 60, 80)         513
# |    |    |    └─relu1       ReLU                  (-1, 128, 60, 80)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 60, 80)         16,384
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 60, 80)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 60, 80)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 60, 80)          36,864
# |    |    └─denselayer2      _DenseLayer           (-1, 32, 60, 80)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 160, 60, 80)         641
# |    |    |    └─relu1       ReLU                  (-1, 160, 60, 80)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 60, 80)         20,480
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 60, 80)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 60, 80)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 60, 80)          36,864
# |    |    └─denselayer3      _DenseLayer           (-1, 32, 60, 80)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 192, 60, 80)         769
# |    |    |    └─relu1       ReLU                  (-1, 192, 60, 80)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 60, 80)         24,576
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 60, 80)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 60, 80)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 60, 80)          36,864
# |    |    └─denselayer4      _DenseLayer           (-1, 32, 60, 80)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 224, 60, 80)         897
# |    |    |    └─relu1       ReLU                  (-1, 224, 60, 80)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 60, 80)         28,672
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 60, 80)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 60, 80)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 60, 80)          36,864
# |    |    └─denselayer5      _DenseLayer           (-1, 32, 60, 80)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 256, 60, 80)         1,025
# |    |    |    └─relu1       ReLU                  (-1, 256, 60, 80)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 60, 80)         32,768
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 60, 80)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 60, 80)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 60, 80)          36,864
# |    |    └─denselayer6      _DenseLayer           (-1, 32, 60, 80)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 288, 60, 80)         1,153
# |    |    |    └─relu1       ReLU                  (-1, 288, 60, 80)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 60, 80)         36,864
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 60, 80)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 60, 80)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 60, 80)          36,864
# |    |    └─denselayer7      _DenseLayer           (-1, 32, 60, 80)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 320, 60, 80)         1,281
# |    |    |    └─relu1       ReLU                  (-1, 320, 60, 80)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 60, 80)         40,960
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 60, 80)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 60, 80)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 60, 80)          36,864
# |    |    └─denselayer8      _DenseLayer           (-1, 32, 60, 80)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 352, 60, 80)         1,409
# |    |    |    └─relu1       ReLU                  (-1, 352, 60, 80)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 60, 80)         45,056
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 60, 80)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 60, 80)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 60, 80)          36,864
# |    |    └─denselayer9      _DenseLayer           (-1, 32, 60, 80)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 384, 60, 80)         1,537
# |    |    |    └─relu1       ReLU                  (-1, 384, 60, 80)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 60, 80)         49,152
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 60, 80)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 60, 80)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 60, 80)          36,864
# |    |    └─denselayer10     _DenseLayer           (-1, 32, 60, 80)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 416, 60, 80)         1,665
# |    |    |    └─relu1       ReLU                  (-1, 416, 60, 80)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 60, 80)         53,248
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 60, 80)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 60, 80)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 60, 80)          36,864
# |    |    └─denselayer11     _DenseLayer           (-1, 32, 60, 80)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 448, 60, 80)         1,793
# |    |    |    └─relu1       ReLU                  (-1, 448, 60, 80)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 60, 80)         57,344
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 60, 80)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 60, 80)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 60, 80)          36,864
# |    |    └─denselayer12     _DenseLayer           (-1, 32, 60, 80)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 480, 60, 80)         1,921
# |    |    |    └─relu1       ReLU                  (-1, 480, 60, 80)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 60, 80)         61,440
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 60, 80)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 60, 80)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 60, 80)          36,864
# |    └─1                     _Transition           (-1, 256, 30, 40)         0
# |    |    └─norm             BatchNorm2d           (-1, 512, 60, 80)         2,049
# |    |    └─relu             ReLU                  (-1, 512, 60, 80)         0
# |    |    └─conv             Conv2d                (-1, 256, 60, 80)         131,072
# |    |    └─pool             AvgPool2d             (-1, 256, 30, 40)         0
# ├─block4                     Sequential            (-1, 1664, 15, 20)        0
# |    └─0                     _DenseBlock           (-1, 1280, 30, 40)        0
# |    |    └─denselayer1      _DenseLayer           (-1, 32, 30, 40)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 256, 30, 40)         1,025
# |    |    |    └─relu1       ReLU                  (-1, 256, 30, 40)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 30, 40)         32,768
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 30, 40)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 30, 40)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 30, 40)          36,864
# |    |    └─denselayer2      _DenseLayer           (-1, 32, 30, 40)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 288, 30, 40)         1,153
# |    |    |    └─relu1       ReLU                  (-1, 288, 30, 40)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 30, 40)         36,864
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 30, 40)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 30, 40)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 30, 40)          36,864
# |    |    └─denselayer3      _DenseLayer           (-1, 32, 30, 40)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 320, 30, 40)         1,281
# |    |    |    └─relu1       ReLU                  (-1, 320, 30, 40)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 30, 40)         40,960
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 30, 40)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 30, 40)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 30, 40)          36,864
# |    |    └─denselayer4      _DenseLayer           (-1, 32, 30, 40)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 352, 30, 40)         1,409
# |    |    |    └─relu1       ReLU                  (-1, 352, 30, 40)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 30, 40)         45,056
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 30, 40)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 30, 40)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 30, 40)          36,864
# |    |    └─denselayer5      _DenseLayer           (-1, 32, 30, 40)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 384, 30, 40)         1,537
# |    |    |    └─relu1       ReLU                  (-1, 384, 30, 40)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 30, 40)         49,152
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 30, 40)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 30, 40)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 30, 40)          36,864
# |    |    └─denselayer6      _DenseLayer           (-1, 32, 30, 40)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 416, 30, 40)         1,665
# |    |    |    └─relu1       ReLU                  (-1, 416, 30, 40)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 30, 40)         53,248
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 30, 40)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 30, 40)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 30, 40)          36,864
# |    |    └─denselayer7      _DenseLayer           (-1, 32, 30, 40)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 448, 30, 40)         1,793
# |    |    |    └─relu1       ReLU                  (-1, 448, 30, 40)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 30, 40)         57,344
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 30, 40)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 30, 40)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 30, 40)          36,864
# |    |    └─denselayer8      _DenseLayer           (-1, 32, 30, 40)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 480, 30, 40)         1,921
# |    |    |    └─relu1       ReLU                  (-1, 480, 30, 40)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 30, 40)         61,440
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 30, 40)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 30, 40)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 30, 40)          36,864
# |    |    └─denselayer9      _DenseLayer           (-1, 32, 30, 40)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 512, 30, 40)         2,049
# |    |    |    └─relu1       ReLU                  (-1, 512, 30, 40)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 30, 40)         65,536
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 30, 40)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 30, 40)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 30, 40)          36,864
# |    |    └─denselayer10     _DenseLayer           (-1, 32, 30, 40)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 544, 30, 40)         2,177
# |    |    |    └─relu1       ReLU                  (-1, 544, 30, 40)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 30, 40)         69,632
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 30, 40)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 30, 40)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 30, 40)          36,864
# |    |    └─denselayer11     _DenseLayer           (-1, 32, 30, 40)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 576, 30, 40)         2,305
# |    |    |    └─relu1       ReLU                  (-1, 576, 30, 40)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 30, 40)         73,728
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 30, 40)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 30, 40)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 30, 40)          36,864
# |    |    └─denselayer12     _DenseLayer           (-1, 32, 30, 40)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 608, 30, 40)         2,433
# |    |    |    └─relu1       ReLU                  (-1, 608, 30, 40)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 30, 40)         77,824
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 30, 40)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 30, 40)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 30, 40)          36,864
# |    |    └─denselayer13     _DenseLayer           (-1, 32, 30, 40)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 640, 30, 40)         2,561
# |    |    |    └─relu1       ReLU                  (-1, 640, 30, 40)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 30, 40)         81,920
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 30, 40)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 30, 40)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 30, 40)          36,864
# |    |    └─denselayer14     _DenseLayer           (-1, 32, 30, 40)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 672, 30, 40)         2,689
# |    |    |    └─relu1       ReLU                  (-1, 672, 30, 40)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 30, 40)         86,016
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 30, 40)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 30, 40)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 30, 40)          36,864
# |    |    └─denselayer15     _DenseLayer           (-1, 32, 30, 40)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 704, 30, 40)         2,817
# |    |    |    └─relu1       ReLU                  (-1, 704, 30, 40)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 30, 40)         90,112
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 30, 40)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 30, 40)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 30, 40)          36,864
# |    |    └─denselayer16     _DenseLayer           (-1, 32, 30, 40)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 736, 30, 40)         2,945
# |    |    |    └─relu1       ReLU                  (-1, 736, 30, 40)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 30, 40)         94,208
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 30, 40)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 30, 40)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 30, 40)          36,864
# |    |    └─denselayer17     _DenseLayer           (-1, 32, 30, 40)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 768, 30, 40)         3,073
# |    |    |    └─relu1       ReLU                  (-1, 768, 30, 40)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 30, 40)         98,304
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 30, 40)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 30, 40)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 30, 40)          36,864
# |    |    └─denselayer18     _DenseLayer           (-1, 32, 30, 40)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 800, 30, 40)         3,201
# |    |    |    └─relu1       ReLU                  (-1, 800, 30, 40)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 30, 40)         102,400
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 30, 40)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 30, 40)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 30, 40)          36,864
# |    |    └─denselayer19     _DenseLayer           (-1, 32, 30, 40)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 832, 30, 40)         3,329
# |    |    |    └─relu1       ReLU                  (-1, 832, 30, 40)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 30, 40)         106,496
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 30, 40)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 30, 40)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 30, 40)          36,864
# |    |    └─denselayer20     _DenseLayer           (-1, 32, 30, 40)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 864, 30, 40)         3,457
# |    |    |    └─relu1       ReLU                  (-1, 864, 30, 40)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 30, 40)         110,592
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 30, 40)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 30, 40)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 30, 40)          36,864
# |    |    └─denselayer21     _DenseLayer           (-1, 32, 30, 40)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 896, 30, 40)         3,585
# |    |    |    └─relu1       ReLU                  (-1, 896, 30, 40)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 30, 40)         114,688
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 30, 40)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 30, 40)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 30, 40)          36,864
# |    |    └─denselayer22     _DenseLayer           (-1, 32, 30, 40)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 928, 30, 40)         3,713
# |    |    |    └─relu1       ReLU                  (-1, 928, 30, 40)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 30, 40)         118,784
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 30, 40)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 30, 40)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 30, 40)          36,864
# |    |    └─denselayer23     _DenseLayer           (-1, 32, 30, 40)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 960, 30, 40)         3,841
# |    |    |    └─relu1       ReLU                  (-1, 960, 30, 40)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 30, 40)         122,880
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 30, 40)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 30, 40)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 30, 40)          36,864
# |    |    └─denselayer24     _DenseLayer           (-1, 32, 30, 40)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 992, 30, 40)         3,969
# |    |    |    └─relu1       ReLU                  (-1, 992, 30, 40)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 30, 40)         126,976
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 30, 40)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 30, 40)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 30, 40)          36,864
# |    |    └─denselayer25     _DenseLayer           (-1, 32, 30, 40)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 1024, 30, 40)        4,097
# |    |    |    └─relu1       ReLU                  (-1, 1024, 30, 40)        0
# |    |    |    └─conv1       Conv2d                (-1, 128, 30, 40)         131,072
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 30, 40)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 30, 40)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 30, 40)          36,864
# |    |    └─denselayer26     _DenseLayer           (-1, 32, 30, 40)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 1056, 30, 40)        4,225
# |    |    |    └─relu1       ReLU                  (-1, 1056, 30, 40)        0
# |    |    |    └─conv1       Conv2d                (-1, 128, 30, 40)         135,168
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 30, 40)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 30, 40)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 30, 40)          36,864
# |    |    └─denselayer27     _DenseLayer           (-1, 32, 30, 40)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 1088, 30, 40)        4,353
# |    |    |    └─relu1       ReLU                  (-1, 1088, 30, 40)        0
# |    |    |    └─conv1       Conv2d                (-1, 128, 30, 40)         139,264
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 30, 40)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 30, 40)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 30, 40)          36,864
# |    |    └─denselayer28     _DenseLayer           (-1, 32, 30, 40)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 1120, 30, 40)        4,481
# |    |    |    └─relu1       ReLU                  (-1, 1120, 30, 40)        0
# |    |    |    └─conv1       Conv2d                (-1, 128, 30, 40)         143,360
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 30, 40)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 30, 40)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 30, 40)          36,864
# |    |    └─denselayer29     _DenseLayer           (-1, 32, 30, 40)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 1152, 30, 40)        4,609
# |    |    |    └─relu1       ReLU                  (-1, 1152, 30, 40)        0
# |    |    |    └─conv1       Conv2d                (-1, 128, 30, 40)         147,456
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 30, 40)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 30, 40)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 30, 40)          36,864
# |    |    └─denselayer30     _DenseLayer           (-1, 32, 30, 40)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 1184, 30, 40)        4,737
# |    |    |    └─relu1       ReLU                  (-1, 1184, 30, 40)        0
# |    |    |    └─conv1       Conv2d                (-1, 128, 30, 40)         151,552
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 30, 40)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 30, 40)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 30, 40)          36,864
# |    |    └─denselayer31     _DenseLayer           (-1, 32, 30, 40)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 1216, 30, 40)        4,865
# |    |    |    └─relu1       ReLU                  (-1, 1216, 30, 40)        0
# |    |    |    └─conv1       Conv2d                (-1, 128, 30, 40)         155,648
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 30, 40)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 30, 40)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 30, 40)          36,864
# |    |    └─denselayer32     _DenseLayer           (-1, 32, 30, 40)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 1248, 30, 40)        4,993
# |    |    |    └─relu1       ReLU                  (-1, 1248, 30, 40)        0
# |    |    |    └─conv1       Conv2d                (-1, 128, 30, 40)         159,744
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 30, 40)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 30, 40)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 30, 40)          36,864
# |    └─1                     _Transition           (-1, 640, 15, 20)         0
# |    |    └─norm             BatchNorm2d           (-1, 1280, 30, 40)        5,121
# |    |    └─relu             ReLU                  (-1, 1280, 30, 40)        0
# |    |    └─conv             Conv2d                (-1, 640, 30, 40)         819,200
# |    |    └─pool             AvgPool2d             (-1, 640, 15, 20)         0
# |    └─2                     _DenseBlock           (-1, 1664, 15, 20)        0
# |    |    └─denselayer1      _DenseLayer           (-1, 32, 15, 20)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 640, 15, 20)         2,561
# |    |    |    └─relu1       ReLU                  (-1, 640, 15, 20)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 15, 20)         81,920
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 15, 20)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 15, 20)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 15, 20)          36,864
# |    |    └─denselayer2      _DenseLayer           (-1, 32, 15, 20)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 672, 15, 20)         2,689
# |    |    |    └─relu1       ReLU                  (-1, 672, 15, 20)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 15, 20)         86,016
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 15, 20)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 15, 20)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 15, 20)          36,864
# |    |    └─denselayer3      _DenseLayer           (-1, 32, 15, 20)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 704, 15, 20)         2,817
# |    |    |    └─relu1       ReLU                  (-1, 704, 15, 20)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 15, 20)         90,112
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 15, 20)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 15, 20)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 15, 20)          36,864
# |    |    └─denselayer4      _DenseLayer           (-1, 32, 15, 20)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 736, 15, 20)         2,945
# |    |    |    └─relu1       ReLU                  (-1, 736, 15, 20)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 15, 20)         94,208
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 15, 20)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 15, 20)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 15, 20)          36,864
# |    |    └─denselayer5      _DenseLayer           (-1, 32, 15, 20)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 768, 15, 20)         3,073
# |    |    |    └─relu1       ReLU                  (-1, 768, 15, 20)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 15, 20)         98,304
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 15, 20)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 15, 20)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 15, 20)          36,864
# |    |    └─denselayer6      _DenseLayer           (-1, 32, 15, 20)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 800, 15, 20)         3,201
# |    |    |    └─relu1       ReLU                  (-1, 800, 15, 20)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 15, 20)         102,400
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 15, 20)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 15, 20)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 15, 20)          36,864
# |    |    └─denselayer7      _DenseLayer           (-1, 32, 15, 20)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 832, 15, 20)         3,329
# |    |    |    └─relu1       ReLU                  (-1, 832, 15, 20)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 15, 20)         106,496
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 15, 20)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 15, 20)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 15, 20)          36,864
# |    |    └─denselayer8      _DenseLayer           (-1, 32, 15, 20)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 864, 15, 20)         3,457
# |    |    |    └─relu1       ReLU                  (-1, 864, 15, 20)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 15, 20)         110,592
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 15, 20)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 15, 20)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 15, 20)          36,864
# |    |    └─denselayer9      _DenseLayer           (-1, 32, 15, 20)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 896, 15, 20)         3,585
# |    |    |    └─relu1       ReLU                  (-1, 896, 15, 20)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 15, 20)         114,688
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 15, 20)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 15, 20)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 15, 20)          36,864
# |    |    └─denselayer10     _DenseLayer           (-1, 32, 15, 20)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 928, 15, 20)         3,713
# |    |    |    └─relu1       ReLU                  (-1, 928, 15, 20)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 15, 20)         118,784
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 15, 20)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 15, 20)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 15, 20)          36,864
# |    |    └─denselayer11     _DenseLayer           (-1, 32, 15, 20)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 960, 15, 20)         3,841
# |    |    |    └─relu1       ReLU                  (-1, 960, 15, 20)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 15, 20)         122,880
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 15, 20)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 15, 20)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 15, 20)          36,864
# |    |    └─denselayer12     _DenseLayer           (-1, 32, 15, 20)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 992, 15, 20)         3,969
# |    |    |    └─relu1       ReLU                  (-1, 992, 15, 20)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 15, 20)         126,976
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 15, 20)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 15, 20)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 15, 20)          36,864
# |    |    └─denselayer13     _DenseLayer           (-1, 32, 15, 20)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 1024, 15, 20)        4,097
# |    |    |    └─relu1       ReLU                  (-1, 1024, 15, 20)        0
# |    |    |    └─conv1       Conv2d                (-1, 128, 15, 20)         131,072
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 15, 20)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 15, 20)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 15, 20)          36,864
# |    |    └─denselayer14     _DenseLayer           (-1, 32, 15, 20)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 1056, 15, 20)        4,225
# |    |    |    └─relu1       ReLU                  (-1, 1056, 15, 20)        0
# |    |    |    └─conv1       Conv2d                (-1, 128, 15, 20)         135,168
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 15, 20)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 15, 20)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 15, 20)          36,864
# |    |    └─denselayer15     _DenseLayer           (-1, 32, 15, 20)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 1088, 15, 20)        4,353
# |    |    |    └─relu1       ReLU                  (-1, 1088, 15, 20)        0
# |    |    |    └─conv1       Conv2d                (-1, 128, 15, 20)         139,264
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 15, 20)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 15, 20)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 15, 20)          36,864
# |    |    └─denselayer16     _DenseLayer           (-1, 32, 15, 20)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 1120, 15, 20)        4,481
# |    |    |    └─relu1       ReLU                  (-1, 1120, 15, 20)        0
# |    |    |    └─conv1       Conv2d                (-1, 128, 15, 20)         143,360
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 15, 20)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 15, 20)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 15, 20)          36,864
# |    |    └─denselayer17     _DenseLayer           (-1, 32, 15, 20)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 1152, 15, 20)        4,609
# |    |    |    └─relu1       ReLU                  (-1, 1152, 15, 20)        0
# |    |    |    └─conv1       Conv2d                (-1, 128, 15, 20)         147,456
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 15, 20)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 15, 20)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 15, 20)          36,864
# |    |    └─denselayer18     _DenseLayer           (-1, 32, 15, 20)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 1184, 15, 20)        4,737
# |    |    |    └─relu1       ReLU                  (-1, 1184, 15, 20)        0
# |    |    |    └─conv1       Conv2d                (-1, 128, 15, 20)         151,552
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 15, 20)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 15, 20)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 15, 20)          36,864
# |    |    └─denselayer19     _DenseLayer           (-1, 32, 15, 20)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 1216, 15, 20)        4,865
# |    |    |    └─relu1       ReLU                  (-1, 1216, 15, 20)        0
# |    |    |    └─conv1       Conv2d                (-1, 128, 15, 20)         155,648
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 15, 20)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 15, 20)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 15, 20)          36,864
# |    |    └─denselayer20     _DenseLayer           (-1, 32, 15, 20)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 1248, 15, 20)        4,993
# |    |    |    └─relu1       ReLU                  (-1, 1248, 15, 20)        0
# |    |    |    └─conv1       Conv2d                (-1, 128, 15, 20)         159,744
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 15, 20)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 15, 20)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 15, 20)          36,864
# |    |    └─denselayer21     _DenseLayer           (-1, 32, 15, 20)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 1280, 15, 20)        5,121
# |    |    |    └─relu1       ReLU                  (-1, 1280, 15, 20)        0
# |    |    |    └─conv1       Conv2d                (-1, 128, 15, 20)         163,840
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 15, 20)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 15, 20)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 15, 20)          36,864
# |    |    └─denselayer22     _DenseLayer           (-1, 32, 15, 20)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 1312, 15, 20)        5,249
# |    |    |    └─relu1       ReLU                  (-1, 1312, 15, 20)        0
# |    |    |    └─conv1       Conv2d                (-1, 128, 15, 20)         167,936
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 15, 20)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 15, 20)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 15, 20)          36,864
# |    |    └─denselayer23     _DenseLayer           (-1, 32, 15, 20)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 1344, 15, 20)        5,377
# |    |    |    └─relu1       ReLU                  (-1, 1344, 15, 20)        0
# |    |    |    └─conv1       Conv2d                (-1, 128, 15, 20)         172,032
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 15, 20)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 15, 20)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 15, 20)          36,864
# |    |    └─denselayer24     _DenseLayer           (-1, 32, 15, 20)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 1376, 15, 20)        5,505
# |    |    |    └─relu1       ReLU                  (-1, 1376, 15, 20)        0
# |    |    |    └─conv1       Conv2d                (-1, 128, 15, 20)         176,128
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 15, 20)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 15, 20)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 15, 20)          36,864
# |    |    └─denselayer25     _DenseLayer           (-1, 32, 15, 20)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 1408, 15, 20)        5,633
# |    |    |    └─relu1       ReLU                  (-1, 1408, 15, 20)        0
# |    |    |    └─conv1       Conv2d                (-1, 128, 15, 20)         180,224
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 15, 20)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 15, 20)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 15, 20)          36,864
# |    |    └─denselayer26     _DenseLayer           (-1, 32, 15, 20)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 1440, 15, 20)        5,761
# |    |    |    └─relu1       ReLU                  (-1, 1440, 15, 20)        0
# |    |    |    └─conv1       Conv2d                (-1, 128, 15, 20)         184,320
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 15, 20)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 15, 20)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 15, 20)          36,864
# |    |    └─denselayer27     _DenseLayer           (-1, 32, 15, 20)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 1472, 15, 20)        5,889
# |    |    |    └─relu1       ReLU                  (-1, 1472, 15, 20)        0
# |    |    |    └─conv1       Conv2d                (-1, 128, 15, 20)         188,416
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 15, 20)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 15, 20)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 15, 20)          36,864
# |    |    └─denselayer28     _DenseLayer           (-1, 32, 15, 20)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 1504, 15, 20)        6,017
# |    |    |    └─relu1       ReLU                  (-1, 1504, 15, 20)        0
# |    |    |    └─conv1       Conv2d                (-1, 128, 15, 20)         192,512
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 15, 20)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 15, 20)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 15, 20)          36,864
# |    |    └─denselayer29     _DenseLayer           (-1, 32, 15, 20)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 1536, 15, 20)        6,145
# |    |    |    └─relu1       ReLU                  (-1, 1536, 15, 20)        0
# |    |    |    └─conv1       Conv2d                (-1, 128, 15, 20)         196,608
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 15, 20)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 15, 20)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 15, 20)          36,864
# |    |    └─denselayer30     _DenseLayer           (-1, 32, 15, 20)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 1568, 15, 20)        6,273
# |    |    |    └─relu1       ReLU                  (-1, 1568, 15, 20)        0
# |    |    |    └─conv1       Conv2d                (-1, 128, 15, 20)         200,704
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 15, 20)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 15, 20)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 15, 20)          36,864
# |    |    └─denselayer31     _DenseLayer           (-1, 32, 15, 20)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 1600, 15, 20)        6,401
# |    |    |    └─relu1       ReLU                  (-1, 1600, 15, 20)        0
# |    |    |    └─conv1       Conv2d                (-1, 128, 15, 20)         204,800
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 15, 20)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 15, 20)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 15, 20)          36,864
# |    |    └─denselayer32     _DenseLayer           (-1, 32, 15, 20)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 1632, 15, 20)        6,529
# |    |    |    └─relu1       ReLU                  (-1, 1632, 15, 20)        0
# |    |    |    └─conv1       Conv2d                (-1, 128, 15, 20)         208,896
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 15, 20)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 15, 20)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 15, 20)          36,864
# ├─conv2                      Conv2d                (-1, 1664, 15, 20)        2,770,560
# ├─upsample1                  UpSample              (-1, 832, 30, 40)         0
# |    └─upsample              Upsample              (-1, 1664, 30, 40)        0
# |    └─conv1                 Conv2d                (-1, 832, 30, 40)         14,377,792
# |    └─relu1                 LeakyReLU             (-1, 832, 30, 40)         0
# |    └─conv2                 Conv2d                (-1, 832, 30, 40)         6,230,848
# |    └─relu2                 LeakyReLU             (-1, 832, 30, 40)         0
# ├─upsample2                  UpSample              (-1, 416, 60, 80)         0
# |    └─upsample              Upsample              (-1, 832, 60, 80)         0
# |    └─conv1                 Conv2d                (-1, 416, 60, 80)         3,594,656
# |    └─relu1                 LeakyReLU             (-1, 416, 60, 80)         0
# |    └─conv2                 Conv2d                (-1, 416, 60, 80)         1,557,920
# |    └─relu2                 LeakyReLU             (-1, 416, 60, 80)         0
# ├─upsample3                  UpSample              (-1, 208, 120, 160)       0
# |    └─upsample              Upsample              (-1, 416, 120, 160)       0
# |    └─conv1                 Conv2d                (-1, 208, 120, 160)       898,768
# |    └─relu1                 LeakyReLU             (-1, 208, 120, 160)       0
# |    └─conv2                 Conv2d                (-1, 208, 120, 160)       389,584
# |    └─relu2                 LeakyReLU             (-1, 208, 120, 160)       0
# ├─upsample4                  UpSample              (-1, 104, 240, 320)       0
# |    └─upsample              Upsample              (-1, 208, 240, 320)       0
# |    └─conv1                 Conv2d                (-1, 104, 240, 320)       254,696
# |    └─relu1                 LeakyReLU             (-1, 104, 240, 320)       0
# |    └─conv2                 Conv2d                (-1, 104, 240, 320)       97,448
# |    └─relu2                 LeakyReLU             (-1, 104, 240, 320)       0
# ├─conv3                      Conv2d                (-1, 104, 240, 320)       97,448
# ==========================================================================================
# Trainable params: 42,750,872
# Non-trainable params: 0
# Total params: 42,750,872
# ------------------------------------------------------------------------------------------
# Model size (params + buffers): 163.67 Mb
# Framework & CUDA overhead: 0.00 Mb
# Total RAM usage: 163.67 Mb
# ------------------------------------------------------------------------------------------
# Floating Point Operations on forward: 261.29 GFLOPs
# Multiply-Accumulations on forward: 130.67 GMACs
# Direct memory accesses on forward: 130.63 GDMAs
# __________________________________________________________________________________________
# D:\Anaconda\envs\torch\lib\site-packages\torchscan\process\memory.py:32: UserWarning: raised: could not convert string to float: ''. Assuming no GPU is available.
#   warnings.warn(f"raised: {e}. Assuming no GPU is available.")

# %%
summary(densenet, (3, 480, 640))
# Out:
# __________________________________________________________________________________________
# Layer                        Type                  Output Shape              Param #
# ==========================================================================================
# densenet                     DenseNet              (-1, 1000)                0
# ├─features                   Sequential            (-1, 1664, 15, 20)        0
# |    └─conv0                 Conv2d                (-1, 64, 240, 320)        9,408
# |    └─norm0                 BatchNorm2d           (-1, 64, 240, 320)        257
# |    └─relu0                 ReLU                  (-1, 64, 240, 320)        0
# |    └─pool0                 MaxPool2d             (-1, 64, 120, 160)        0
# |    └─denseblock1           _DenseBlock           (-1, 256, 120, 160)       0
# |    |    └─denselayer1      _DenseLayer           (-1, 32, 120, 160)        0
# |    |    |    └─norm1       BatchNorm2d           (-1, 64, 120, 160)        257
# |    |    |    └─relu1       ReLU                  (-1, 64, 120, 160)        0
# |    |    |    └─conv1       Conv2d                (-1, 128, 120, 160)       8,192
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 120, 160)       513
# |    |    |    └─relu2       ReLU                  (-1, 128, 120, 160)       0
# |    |    |    └─conv2       Conv2d                (-1, 32, 120, 160)        36,864
# |    |    └─denselayer2      _DenseLayer           (-1, 32, 120, 160)        0
# |    |    |    └─norm1       BatchNorm2d           (-1, 96, 120, 160)        385
# |    |    |    └─relu1       ReLU                  (-1, 96, 120, 160)        0
# |    |    |    └─conv1       Conv2d                (-1, 128, 120, 160)       12,288
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 120, 160)       513
# |    |    |    └─relu2       ReLU                  (-1, 128, 120, 160)       0
# |    |    |    └─conv2       Conv2d                (-1, 32, 120, 160)        36,864
# |    |    └─denselayer3      _DenseLayer           (-1, 32, 120, 160)        0
# |    |    |    └─norm1       BatchNorm2d           (-1, 128, 120, 160)       513
# |    |    |    └─relu1       ReLU                  (-1, 128, 120, 160)       0
# |    |    |    └─conv1       Conv2d                (-1, 128, 120, 160)       16,384
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 120, 160)       513
# |    |    |    └─relu2       ReLU                  (-1, 128, 120, 160)       0
# |    |    |    └─conv2       Conv2d                (-1, 32, 120, 160)        36,864
# |    |    └─denselayer4      _DenseLayer           (-1, 32, 120, 160)        0
# |    |    |    └─norm1       BatchNorm2d           (-1, 160, 120, 160)       641
# |    |    |    └─relu1       ReLU                  (-1, 160, 120, 160)       0
# |    |    |    └─conv1       Conv2d                (-1, 128, 120, 160)       20,480
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 120, 160)       513
# |    |    |    └─relu2       ReLU                  (-1, 128, 120, 160)       0
# |    |    |    └─conv2       Conv2d                (-1, 32, 120, 160)        36,864
# |    |    └─denselayer5      _DenseLayer           (-1, 32, 120, 160)        0
# |    |    |    └─norm1       BatchNorm2d           (-1, 192, 120, 160)       769
# |    |    |    └─relu1       ReLU                  (-1, 192, 120, 160)       0
# |    |    |    └─conv1       Conv2d                (-1, 128, 120, 160)       24,576
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 120, 160)       513
# |    |    |    └─relu2       ReLU                  (-1, 128, 120, 160)       0
# |    |    |    └─conv2       Conv2d                (-1, 32, 120, 160)        36,864
# |    |    └─denselayer6      _DenseLayer           (-1, 32, 120, 160)        0
# |    |    |    └─norm1       BatchNorm2d           (-1, 224, 120, 160)       897
# |    |    |    └─relu1       ReLU                  (-1, 224, 120, 160)       0
# |    |    |    └─conv1       Conv2d                (-1, 128, 120, 160)       28,672
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 120, 160)       513
# |    |    |    └─relu2       ReLU                  (-1, 128, 120, 160)       0
# |    |    |    └─conv2       Conv2d                (-1, 32, 120, 160)        36,864
# |    └─transition1           _Transition           (-1, 128, 60, 80)         0
# |    |    └─norm             BatchNorm2d           (-1, 256, 120, 160)       1,025
# |    |    └─relu             ReLU                  (-1, 256, 120, 160)       0
# |    |    └─conv             Conv2d                (-1, 128, 120, 160)       32,768
# |    |    └─pool             AvgPool2d             (-1, 128, 60, 80)         0
# |    └─denseblock2           _DenseBlock           (-1, 512, 60, 80)         0
# |    |    └─denselayer1      _DenseLayer           (-1, 32, 60, 80)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 128, 60, 80)         513
# |    |    |    └─relu1       ReLU                  (-1, 128, 60, 80)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 60, 80)         16,384
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 60, 80)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 60, 80)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 60, 80)          36,864
# |    |    └─denselayer2      _DenseLayer           (-1, 32, 60, 80)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 160, 60, 80)         641
# |    |    |    └─relu1       ReLU                  (-1, 160, 60, 80)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 60, 80)         20,480
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 60, 80)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 60, 80)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 60, 80)          36,864
# |    |    └─denselayer3      _DenseLayer           (-1, 32, 60, 80)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 192, 60, 80)         769
# |    |    |    └─relu1       ReLU                  (-1, 192, 60, 80)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 60, 80)         24,576
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 60, 80)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 60, 80)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 60, 80)          36,864
# |    |    └─denselayer4      _DenseLayer           (-1, 32, 60, 80)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 224, 60, 80)         897
# |    |    |    └─relu1       ReLU                  (-1, 224, 60, 80)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 60, 80)         28,672
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 60, 80)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 60, 80)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 60, 80)          36,864
# |    |    └─denselayer5      _DenseLayer           (-1, 32, 60, 80)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 256, 60, 80)         1,025
# |    |    |    └─relu1       ReLU                  (-1, 256, 60, 80)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 60, 80)         32,768
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 60, 80)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 60, 80)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 60, 80)          36,864
# |    |    └─denselayer6      _DenseLayer           (-1, 32, 60, 80)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 288, 60, 80)         1,153
# |    |    |    └─relu1       ReLU                  (-1, 288, 60, 80)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 60, 80)         36,864
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 60, 80)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 60, 80)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 60, 80)          36,864
# |    |    └─denselayer7      _DenseLayer           (-1, 32, 60, 80)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 320, 60, 80)         1,281
# |    |    |    └─relu1       ReLU                  (-1, 320, 60, 80)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 60, 80)         40,960
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 60, 80)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 60, 80)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 60, 80)          36,864
# |    |    └─denselayer8      _DenseLayer           (-1, 32, 60, 80)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 352, 60, 80)         1,409
# |    |    |    └─relu1       ReLU                  (-1, 352, 60, 80)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 60, 80)         45,056
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 60, 80)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 60, 80)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 60, 80)          36,864
# |    |    └─denselayer9      _DenseLayer           (-1, 32, 60, 80)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 384, 60, 80)         1,537
# |    |    |    └─relu1       ReLU                  (-1, 384, 60, 80)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 60, 80)         49,152
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 60, 80)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 60, 80)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 60, 80)          36,864
# |    |    └─denselayer10     _DenseLayer           (-1, 32, 60, 80)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 416, 60, 80)         1,665
# |    |    |    └─relu1       ReLU                  (-1, 416, 60, 80)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 60, 80)         53,248
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 60, 80)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 60, 80)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 60, 80)          36,864
# |    |    └─denselayer11     _DenseLayer           (-1, 32, 60, 80)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 448, 60, 80)         1,793
# |    |    |    └─relu1       ReLU                  (-1, 448, 60, 80)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 60, 80)         57,344
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 60, 80)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 60, 80)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 60, 80)          36,864
# |    |    └─denselayer12     _DenseLayer           (-1, 32, 60, 80)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 480, 60, 80)         1,921
# |    |    |    └─relu1       ReLU                  (-1, 480, 60, 80)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 60, 80)         61,440
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 60, 80)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 60, 80)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 60, 80)          36,864
# |    └─transition2           _Transition           (-1, 256, 30, 40)         0
# |    |    └─norm             BatchNorm2d           (-1, 512, 60, 80)         2,049
# |    |    └─relu             ReLU                  (-1, 512, 60, 80)         0
# |    |    └─conv             Conv2d                (-1, 256, 60, 80)         131,072
# |    |    └─pool             AvgPool2d             (-1, 256, 30, 40)         0
# |    └─denseblock3           _DenseBlock           (-1, 1280, 30, 40)        0
# |    |    └─denselayer1      _DenseLayer           (-1, 32, 30, 40)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 256, 30, 40)         1,025
# |    |    |    └─relu1       ReLU                  (-1, 256, 30, 40)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 30, 40)         32,768
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 30, 40)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 30, 40)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 30, 40)          36,864
# |    |    └─denselayer2      _DenseLayer           (-1, 32, 30, 40)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 288, 30, 40)         1,153
# |    |    |    └─relu1       ReLU                  (-1, 288, 30, 40)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 30, 40)         36,864
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 30, 40)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 30, 40)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 30, 40)          36,864
# |    |    └─denselayer3      _DenseLayer           (-1, 32, 30, 40)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 320, 30, 40)         1,281
# |    |    |    └─relu1       ReLU                  (-1, 320, 30, 40)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 30, 40)         40,960
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 30, 40)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 30, 40)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 30, 40)          36,864
# |    |    └─denselayer4      _DenseLayer           (-1, 32, 30, 40)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 352, 30, 40)         1,409
# |    |    |    └─relu1       ReLU                  (-1, 352, 30, 40)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 30, 40)         45,056
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 30, 40)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 30, 40)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 30, 40)          36,864
# |    |    └─denselayer5      _DenseLayer           (-1, 32, 30, 40)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 384, 30, 40)         1,537
# |    |    |    └─relu1       ReLU                  (-1, 384, 30, 40)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 30, 40)         49,152
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 30, 40)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 30, 40)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 30, 40)          36,864
# |    |    └─denselayer6      _DenseLayer           (-1, 32, 30, 40)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 416, 30, 40)         1,665
# |    |    |    └─relu1       ReLU                  (-1, 416, 30, 40)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 30, 40)         53,248
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 30, 40)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 30, 40)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 30, 40)          36,864
# |    |    └─denselayer7      _DenseLayer           (-1, 32, 30, 40)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 448, 30, 40)         1,793
# |    |    |    └─relu1       ReLU                  (-1, 448, 30, 40)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 30, 40)         57,344
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 30, 40)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 30, 40)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 30, 40)          36,864
# |    |    └─denselayer8      _DenseLayer           (-1, 32, 30, 40)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 480, 30, 40)         1,921
# |    |    |    └─relu1       ReLU                  (-1, 480, 30, 40)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 30, 40)         61,440
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 30, 40)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 30, 40)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 30, 40)          36,864
# |    |    └─denselayer9      _DenseLayer           (-1, 32, 30, 40)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 512, 30, 40)         2,049
# |    |    |    └─relu1       ReLU                  (-1, 512, 30, 40)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 30, 40)         65,536
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 30, 40)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 30, 40)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 30, 40)          36,864
# |    |    └─denselayer10     _DenseLayer           (-1, 32, 30, 40)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 544, 30, 40)         2,177
# |    |    |    └─relu1       ReLU                  (-1, 544, 30, 40)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 30, 40)         69,632
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 30, 40)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 30, 40)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 30, 40)          36,864
# |    |    └─denselayer11     _DenseLayer           (-1, 32, 30, 40)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 576, 30, 40)         2,305
# |    |    |    └─relu1       ReLU                  (-1, 576, 30, 40)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 30, 40)         73,728
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 30, 40)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 30, 40)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 30, 40)          36,864
# |    |    └─denselayer12     _DenseLayer           (-1, 32, 30, 40)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 608, 30, 40)         2,433
# |    |    |    └─relu1       ReLU                  (-1, 608, 30, 40)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 30, 40)         77,824
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 30, 40)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 30, 40)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 30, 40)          36,864
# |    |    └─denselayer13     _DenseLayer           (-1, 32, 30, 40)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 640, 30, 40)         2,561
# |    |    |    └─relu1       ReLU                  (-1, 640, 30, 40)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 30, 40)         81,920
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 30, 40)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 30, 40)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 30, 40)          36,864
# |    |    └─denselayer14     _DenseLayer           (-1, 32, 30, 40)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 672, 30, 40)         2,689
# |    |    |    └─relu1       ReLU                  (-1, 672, 30, 40)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 30, 40)         86,016
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 30, 40)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 30, 40)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 30, 40)          36,864
# |    |    └─denselayer15     _DenseLayer           (-1, 32, 30, 40)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 704, 30, 40)         2,817
# |    |    |    └─relu1       ReLU                  (-1, 704, 30, 40)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 30, 40)         90,112
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 30, 40)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 30, 40)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 30, 40)          36,864
# |    |    └─denselayer16     _DenseLayer           (-1, 32, 30, 40)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 736, 30, 40)         2,945
# |    |    |    └─relu1       ReLU                  (-1, 736, 30, 40)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 30, 40)         94,208
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 30, 40)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 30, 40)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 30, 40)          36,864
# |    |    └─denselayer17     _DenseLayer           (-1, 32, 30, 40)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 768, 30, 40)         3,073
# |    |    |    └─relu1       ReLU                  (-1, 768, 30, 40)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 30, 40)         98,304
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 30, 40)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 30, 40)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 30, 40)          36,864
# |    |    └─denselayer18     _DenseLayer           (-1, 32, 30, 40)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 800, 30, 40)         3,201
# |    |    |    └─relu1       ReLU                  (-1, 800, 30, 40)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 30, 40)         102,400
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 30, 40)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 30, 40)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 30, 40)          36,864
# |    |    └─denselayer19     _DenseLayer           (-1, 32, 30, 40)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 832, 30, 40)         3,329
# |    |    |    └─relu1       ReLU                  (-1, 832, 30, 40)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 30, 40)         106,496
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 30, 40)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 30, 40)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 30, 40)          36,864
# |    |    └─denselayer20     _DenseLayer           (-1, 32, 30, 40)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 864, 30, 40)         3,457
# |    |    |    └─relu1       ReLU                  (-1, 864, 30, 40)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 30, 40)         110,592
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 30, 40)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 30, 40)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 30, 40)          36,864
# |    |    └─denselayer21     _DenseLayer           (-1, 32, 30, 40)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 896, 30, 40)         3,585
# |    |    |    └─relu1       ReLU                  (-1, 896, 30, 40)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 30, 40)         114,688
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 30, 40)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 30, 40)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 30, 40)          36,864
# |    |    └─denselayer22     _DenseLayer           (-1, 32, 30, 40)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 928, 30, 40)         3,713
# |    |    |    └─relu1       ReLU                  (-1, 928, 30, 40)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 30, 40)         118,784
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 30, 40)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 30, 40)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 30, 40)          36,864
# |    |    └─denselayer23     _DenseLayer           (-1, 32, 30, 40)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 960, 30, 40)         3,841
# |    |    |    └─relu1       ReLU                  (-1, 960, 30, 40)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 30, 40)         122,880
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 30, 40)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 30, 40)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 30, 40)          36,864
# |    |    └─denselayer24     _DenseLayer           (-1, 32, 30, 40)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 992, 30, 40)         3,969
# |    |    |    └─relu1       ReLU                  (-1, 992, 30, 40)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 30, 40)         126,976
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 30, 40)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 30, 40)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 30, 40)          36,864
# |    |    └─denselayer25     _DenseLayer           (-1, 32, 30, 40)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 1024, 30, 40)        4,097
# |    |    |    └─relu1       ReLU                  (-1, 1024, 30, 40)        0
# |    |    |    └─conv1       Conv2d                (-1, 128, 30, 40)         131,072
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 30, 40)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 30, 40)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 30, 40)          36,864
# |    |    └─denselayer26     _DenseLayer           (-1, 32, 30, 40)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 1056, 30, 40)        4,225
# |    |    |    └─relu1       ReLU                  (-1, 1056, 30, 40)        0
# |    |    |    └─conv1       Conv2d                (-1, 128, 30, 40)         135,168
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 30, 40)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 30, 40)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 30, 40)          36,864
# |    |    └─denselayer27     _DenseLayer           (-1, 32, 30, 40)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 1088, 30, 40)        4,353
# |    |    |    └─relu1       ReLU                  (-1, 1088, 30, 40)        0
# |    |    |    └─conv1       Conv2d                (-1, 128, 30, 40)         139,264
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 30, 40)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 30, 40)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 30, 40)          36,864
# |    |    └─denselayer28     _DenseLayer           (-1, 32, 30, 40)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 1120, 30, 40)        4,481
# |    |    |    └─relu1       ReLU                  (-1, 1120, 30, 40)        0
# |    |    |    └─conv1       Conv2d                (-1, 128, 30, 40)         143,360
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 30, 40)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 30, 40)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 30, 40)          36,864
# |    |    └─denselayer29     _DenseLayer           (-1, 32, 30, 40)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 1152, 30, 40)        4,609
# |    |    |    └─relu1       ReLU                  (-1, 1152, 30, 40)        0
# |    |    |    └─conv1       Conv2d                (-1, 128, 30, 40)         147,456
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 30, 40)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 30, 40)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 30, 40)          36,864
# |    |    └─denselayer30     _DenseLayer           (-1, 32, 30, 40)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 1184, 30, 40)        4,737
# |    |    |    └─relu1       ReLU                  (-1, 1184, 30, 40)        0
# |    |    |    └─conv1       Conv2d                (-1, 128, 30, 40)         151,552
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 30, 40)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 30, 40)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 30, 40)          36,864
# |    |    └─denselayer31     _DenseLayer           (-1, 32, 30, 40)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 1216, 30, 40)        4,865
# |    |    |    └─relu1       ReLU                  (-1, 1216, 30, 40)        0
# |    |    |    └─conv1       Conv2d                (-1, 128, 30, 40)         155,648
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 30, 40)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 30, 40)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 30, 40)          36,864
# |    |    └─denselayer32     _DenseLayer           (-1, 32, 30, 40)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 1248, 30, 40)        4,993
# |    |    |    └─relu1       ReLU                  (-1, 1248, 30, 40)        0
# |    |    |    └─conv1       Conv2d                (-1, 128, 30, 40)         159,744
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 30, 40)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 30, 40)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 30, 40)          36,864
# |    └─transition3           _Transition           (-1, 640, 15, 20)         0
# |    |    └─norm             BatchNorm2d           (-1, 1280, 30, 40)        5,121
# |    |    └─relu             ReLU                  (-1, 1280, 30, 40)        0
# |    |    └─conv             Conv2d                (-1, 640, 30, 40)         819,200
# |    |    └─pool             AvgPool2d             (-1, 640, 15, 20)         0
# |    └─denseblock4           _DenseBlock           (-1, 1664, 15, 20)        0
# |    |    └─denselayer1      _DenseLayer           (-1, 32, 15, 20)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 640, 15, 20)         2,561
# |    |    |    └─relu1       ReLU                  (-1, 640, 15, 20)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 15, 20)         81,920
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 15, 20)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 15, 20)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 15, 20)          36,864
# |    |    └─denselayer2      _DenseLayer           (-1, 32, 15, 20)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 672, 15, 20)         2,689
# |    |    |    └─relu1       ReLU                  (-1, 672, 15, 20)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 15, 20)         86,016
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 15, 20)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 15, 20)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 15, 20)          36,864
# |    |    └─denselayer3      _DenseLayer           (-1, 32, 15, 20)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 704, 15, 20)         2,817
# |    |    |    └─relu1       ReLU                  (-1, 704, 15, 20)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 15, 20)         90,112
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 15, 20)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 15, 20)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 15, 20)          36,864
# |    |    └─denselayer4      _DenseLayer           (-1, 32, 15, 20)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 736, 15, 20)         2,945
# |    |    |    └─relu1       ReLU                  (-1, 736, 15, 20)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 15, 20)         94,208
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 15, 20)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 15, 20)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 15, 20)          36,864
# |    |    └─denselayer5      _DenseLayer           (-1, 32, 15, 20)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 768, 15, 20)         3,073
# |    |    |    └─relu1       ReLU                  (-1, 768, 15, 20)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 15, 20)         98,304
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 15, 20)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 15, 20)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 15, 20)          36,864
# |    |    └─denselayer6      _DenseLayer           (-1, 32, 15, 20)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 800, 15, 20)         3,201
# |    |    |    └─relu1       ReLU                  (-1, 800, 15, 20)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 15, 20)         102,400
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 15, 20)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 15, 20)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 15, 20)          36,864
# |    |    └─denselayer7      _DenseLayer           (-1, 32, 15, 20)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 832, 15, 20)         3,329
# |    |    |    └─relu1       ReLU                  (-1, 832, 15, 20)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 15, 20)         106,496
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 15, 20)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 15, 20)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 15, 20)          36,864
# |    |    └─denselayer8      _DenseLayer           (-1, 32, 15, 20)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 864, 15, 20)         3,457
# |    |    |    └─relu1       ReLU                  (-1, 864, 15, 20)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 15, 20)         110,592
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 15, 20)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 15, 20)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 15, 20)          36,864
# |    |    └─denselayer9      _DenseLayer           (-1, 32, 15, 20)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 896, 15, 20)         3,585
# |    |    |    └─relu1       ReLU                  (-1, 896, 15, 20)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 15, 20)         114,688
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 15, 20)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 15, 20)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 15, 20)          36,864
# |    |    └─denselayer10     _DenseLayer           (-1, 32, 15, 20)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 928, 15, 20)         3,713
# |    |    |    └─relu1       ReLU                  (-1, 928, 15, 20)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 15, 20)         118,784
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 15, 20)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 15, 20)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 15, 20)          36,864
# |    |    └─denselayer11     _DenseLayer           (-1, 32, 15, 20)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 960, 15, 20)         3,841
# |    |    |    └─relu1       ReLU                  (-1, 960, 15, 20)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 15, 20)         122,880
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 15, 20)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 15, 20)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 15, 20)          36,864
# |    |    └─denselayer12     _DenseLayer           (-1, 32, 15, 20)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 992, 15, 20)         3,969
# |    |    |    └─relu1       ReLU                  (-1, 992, 15, 20)         0
# |    |    |    └─conv1       Conv2d                (-1, 128, 15, 20)         126,976
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 15, 20)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 15, 20)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 15, 20)          36,864
# |    |    └─denselayer13     _DenseLayer           (-1, 32, 15, 20)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 1024, 15, 20)        4,097
# |    |    |    └─relu1       ReLU                  (-1, 1024, 15, 20)        0
# |    |    |    └─conv1       Conv2d                (-1, 128, 15, 20)         131,072
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 15, 20)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 15, 20)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 15, 20)          36,864
# |    |    └─denselayer14     _DenseLayer           (-1, 32, 15, 20)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 1056, 15, 20)        4,225
# |    |    |    └─relu1       ReLU                  (-1, 1056, 15, 20)        0
# |    |    |    └─conv1       Conv2d                (-1, 128, 15, 20)         135,168
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 15, 20)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 15, 20)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 15, 20)          36,864
# |    |    └─denselayer15     _DenseLayer           (-1, 32, 15, 20)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 1088, 15, 20)        4,353
# |    |    |    └─relu1       ReLU                  (-1, 1088, 15, 20)        0
# |    |    |    └─conv1       Conv2d                (-1, 128, 15, 20)         139,264
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 15, 20)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 15, 20)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 15, 20)          36,864
# |    |    └─denselayer16     _DenseLayer           (-1, 32, 15, 20)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 1120, 15, 20)        4,481
# |    |    |    └─relu1       ReLU                  (-1, 1120, 15, 20)        0
# |    |    |    └─conv1       Conv2d                (-1, 128, 15, 20)         143,360
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 15, 20)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 15, 20)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 15, 20)          36,864
# |    |    └─denselayer17     _DenseLayer           (-1, 32, 15, 20)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 1152, 15, 20)        4,609
# |    |    |    └─relu1       ReLU                  (-1, 1152, 15, 20)        0
# |    |    |    └─conv1       Conv2d                (-1, 128, 15, 20)         147,456
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 15, 20)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 15, 20)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 15, 20)          36,864
# |    |    └─denselayer18     _DenseLayer           (-1, 32, 15, 20)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 1184, 15, 20)        4,737
# |    |    |    └─relu1       ReLU                  (-1, 1184, 15, 20)        0
# |    |    |    └─conv1       Conv2d                (-1, 128, 15, 20)         151,552
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 15, 20)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 15, 20)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 15, 20)          36,864
# |    |    └─denselayer19     _DenseLayer           (-1, 32, 15, 20)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 1216, 15, 20)        4,865
# |    |    |    └─relu1       ReLU                  (-1, 1216, 15, 20)        0
# |    |    |    └─conv1       Conv2d                (-1, 128, 15, 20)         155,648
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 15, 20)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 15, 20)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 15, 20)          36,864
# |    |    └─denselayer20     _DenseLayer           (-1, 32, 15, 20)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 1248, 15, 20)        4,993
# |    |    |    └─relu1       ReLU                  (-1, 1248, 15, 20)        0
# |    |    |    └─conv1       Conv2d                (-1, 128, 15, 20)         159,744
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 15, 20)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 15, 20)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 15, 20)          36,864
# |    |    └─denselayer21     _DenseLayer           (-1, 32, 15, 20)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 1280, 15, 20)        5,121
# |    |    |    └─relu1       ReLU                  (-1, 1280, 15, 20)        0
# |    |    |    └─conv1       Conv2d                (-1, 128, 15, 20)         163,840
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 15, 20)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 15, 20)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 15, 20)          36,864
# |    |    └─denselayer22     _DenseLayer           (-1, 32, 15, 20)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 1312, 15, 20)        5,249
# |    |    |    └─relu1       ReLU                  (-1, 1312, 15, 20)        0
# |    |    |    └─conv1       Conv2d                (-1, 128, 15, 20)         167,936
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 15, 20)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 15, 20)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 15, 20)          36,864
# |    |    └─denselayer23     _DenseLayer           (-1, 32, 15, 20)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 1344, 15, 20)        5,377
# |    |    |    └─relu1       ReLU                  (-1, 1344, 15, 20)        0
# |    |    |    └─conv1       Conv2d                (-1, 128, 15, 20)         172,032
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 15, 20)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 15, 20)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 15, 20)          36,864
# |    |    └─denselayer24     _DenseLayer           (-1, 32, 15, 20)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 1376, 15, 20)        5,505
# |    |    |    └─relu1       ReLU                  (-1, 1376, 15, 20)        0
# |    |    |    └─conv1       Conv2d                (-1, 128, 15, 20)         176,128
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 15, 20)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 15, 20)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 15, 20)          36,864
# |    |    └─denselayer25     _DenseLayer           (-1, 32, 15, 20)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 1408, 15, 20)        5,633
# |    |    |    └─relu1       ReLU                  (-1, 1408, 15, 20)        0
# |    |    |    └─conv1       Conv2d                (-1, 128, 15, 20)         180,224
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 15, 20)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 15, 20)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 15, 20)          36,864
# |    |    └─denselayer26     _DenseLayer           (-1, 32, 15, 20)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 1440, 15, 20)        5,761
# |    |    |    └─relu1       ReLU                  (-1, 1440, 15, 20)        0
# |    |    |    └─conv1       Conv2d                (-1, 128, 15, 20)         184,320
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 15, 20)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 15, 20)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 15, 20)          36,864
# |    |    └─denselayer27     _DenseLayer           (-1, 32, 15, 20)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 1472, 15, 20)        5,889
# |    |    |    └─relu1       ReLU                  (-1, 1472, 15, 20)        0
# |    |    |    └─conv1       Conv2d                (-1, 128, 15, 20)         188,416
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 15, 20)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 15, 20)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 15, 20)          36,864
# |    |    └─denselayer28     _DenseLayer           (-1, 32, 15, 20)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 1504, 15, 20)        6,017
# |    |    |    └─relu1       ReLU                  (-1, 1504, 15, 20)        0
# |    |    |    └─conv1       Conv2d                (-1, 128, 15, 20)         192,512
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 15, 20)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 15, 20)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 15, 20)          36,864
# |    |    └─denselayer29     _DenseLayer           (-1, 32, 15, 20)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 1536, 15, 20)        6,145
# |    |    |    └─relu1       ReLU                  (-1, 1536, 15, 20)        0
# |    |    |    └─conv1       Conv2d                (-1, 128, 15, 20)         196,608
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 15, 20)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 15, 20)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 15, 20)          36,864
# |    |    └─denselayer30     _DenseLayer           (-1, 32, 15, 20)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 1568, 15, 20)        6,273
# |    |    |    └─relu1       ReLU                  (-1, 1568, 15, 20)        0
# |    |    |    └─conv1       Conv2d                (-1, 128, 15, 20)         200,704
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 15, 20)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 15, 20)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 15, 20)          36,864
# |    |    └─denselayer31     _DenseLayer           (-1, 32, 15, 20)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 1600, 15, 20)        6,401
# |    |    |    └─relu1       ReLU                  (-1, 1600, 15, 20)        0
# |    |    |    └─conv1       Conv2d                (-1, 128, 15, 20)         204,800
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 15, 20)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 15, 20)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 15, 20)          36,864
# |    |    └─denselayer32     _DenseLayer           (-1, 32, 15, 20)          0
# |    |    |    └─norm1       BatchNorm2d           (-1, 1632, 15, 20)        6,529
# |    |    |    └─relu1       ReLU                  (-1, 1632, 15, 20)        0
# |    |    |    └─conv1       Conv2d                (-1, 128, 15, 20)         208,896
# |    |    |    └─norm2       BatchNorm2d           (-1, 128, 15, 20)         513
# |    |    |    └─relu2       ReLU                  (-1, 128, 15, 20)         0
# |    |    |    └─conv2       Conv2d                (-1, 32, 15, 20)          36,864
# |    └─norm5                 BatchNorm2d           (-1, 1664, 15, 20)        6,657
# ├─classifier                 Linear                (-1, 1000)                1,665,000
# ==========================================================================================
# Trainable params: 14,149,480
# Non-trainable params: 0
# Total params: 14,149,480
# ------------------------------------------------------------------------------------------
# Model size (params + buffers): 54.58 Mb
# Framework & CUDA overhead: 0.00 Mb
# Total RAM usage: 54.58 Mb
# ------------------------------------------------------------------------------------------
# Floating Point Operations on forward: 42.13 GFLOPs
# Multiply-Accumulations on forward: 21.15 GMACs
# Direct memory accesses on forward: 20.99 GDMAs
# __________________________________________________________________________________________

# %%
class UpSample(nn.Sequential):
    def __init__(self, skip_input, output_features):
        super(UpSample, self).__init__()        
        self.convA = nn.Conv2d(skip_input, output_features, kernel_size=3, stride=1, padding=1)
        self.leakyreluA = nn.LeakyReLU(0.2)
        self.convB = nn.Conv2d(output_features, output_features, kernel_size=3, stride=1, padding=1)
        self.leakyreluB = nn.LeakyReLU(0.2)

    def forward(self, x, concat_with):
        up_x = F.interpolate(x, size=[concat_with.size(2), concat_with.size(3)], mode='bilinear', align_corners=True)
        return self.leakyreluB( self.convB( self.leakyreluA(self.convA( torch.cat([up_x, concat_with], dim=1) ) ) )  )

class Decoder(nn.Module):
    def __init__(self, num_features=2208, decoder_width = 0.5):
        super(Decoder, self).__init__()
        features = int(num_features * decoder_width)

        self.conv2 = nn.Conv2d(num_features, features, kernel_size=1, stride=1, padding=1)

        self.up1 = UpSample(skip_input=features//1 + 384, output_features=features//2)
        self.up2 = UpSample(skip_input=features//2 + 192, output_features=features//4)
        self.up3 = UpSample(skip_input=features//4 +  96, output_features=features//8)
        self.up4 = UpSample(skip_input=features//8 +  96, output_features=features//16)

        self.conv3 = nn.Conv2d(features//16, 1, kernel_size=3, stride=1, padding=1)

    def forward(self, features):
        x_block0, x_block1, x_block2, x_block3, x_block4 = features[3], features[4], features[6], features[8], features[11]
        x_d0 = self.conv2(x_block4)
        x_d1 = self.up1(x_d0, x_block3)
        x_d2 = self.up2(x_d1, x_block2)
        x_d3 = self.up3(x_d2, x_block1)
        x_d4 = self.up4(x_d3, x_block0)
        return self.conv3(x_d4)

class Encoder(nn.Module):
    def __init__(self):
        super(Encoder, self).__init__()       
        import torchvision.models as models
        self.original_model = models.densenet161( pretrained=False )

    def forward(self, x):
        features = [x]
        for k, v in self.original_model.features._modules.items(): features.append( v(features[-1]) )
        return features

class Model(nn.Module):
    def __init__(self):
        super(Model, self).__init__()
        self.encoder = Encoder()
        self.decoder = Decoder()

    def forward(self, x):
        return self.decoder( self.encoder(x) )

# %%
t = Model()
